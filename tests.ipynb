# %%
from matplotlib import pyplot as plt

# %%
plt.annotate(
    'long long long\nlong long long\nlong long long\nlong long long\n text',
    (0.2, 0.2),
    xytext=(0.6, 0.3),
    arrowprops={
        'facecolor': 'black',
        'shrink': 0.02
    }
)
plt.show()
